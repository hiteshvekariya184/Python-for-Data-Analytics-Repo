# %% [markdown]
# # Printing of my name and my favorite app
# ##### through print() function

# %%
print("My name is Hitesh Vekariya")
print("My favorite application is gaming application and my favorite game is candy crush saga")
# Out:
# My name is Hitesh Vekariya
# My favorite application is gaming application and my favorite game is candy crush saga
