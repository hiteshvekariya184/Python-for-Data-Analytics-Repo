# %% [markdown]
# ### Printing of Data & time through importing the Datetime liberary

# %%
import datetime

current_time = datetime.datetime.now()
current_year = current_time.year

print("Current date and time: ", current_time.strftime("%d-%m-%Y %H:%M:%S")) # use to change the format of the date and time
print("Current year: ", current_year)
# Out:
# Current date and time:  13-09-2026 14:31:38
# Current year:  2026
