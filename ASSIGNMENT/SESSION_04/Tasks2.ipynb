# %% [markdown]
# ### Creation of function in which it's functionality is to clean unwanted spaces

# %%
def clean_brand_name(name):
    name = name.strip() # Its remove extra spaces.
    name = name.replace("-", " ")

    return name

brand_name = clean_brand_name(" oneplus-Nord ")

print(brand_name)  # Output: "oneplus Nord"
# Out:
# oneplus Nord
