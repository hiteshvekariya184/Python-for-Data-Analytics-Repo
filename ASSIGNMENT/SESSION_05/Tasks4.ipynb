# %% [markdown]
# ### using of tuple

# %%
# Create a tuple with 4 Instagram filter names
insta_filters = ("Clarendon", "Juno", "Lark", "Gingham")

# Try to update the second filter
insta_filters[1] = "Valencia"

# This will give a TypeError because tuples are immutable.
# We cannot change, add, or remove individual items from a tuple.

"""
    A tuple is immutable, which means once it is created, its values cannot be changed.
        insta_filters[1] = "Valencia"
    is not allowed because we are trying to change the second item.

    If we need have to change the items, then usage a list is needed instead tuple
    
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # Create a tuple with 4 Instagram filter names
#       2 insta_filters = ("Clarendon", "Juno", "Lark", "Gingham")
#       3
#       4 # Try to update the second filter
# ----> 5 insta_filters[1] = "Valencia"
#       6
#       7 # This will give a TypeError because tuples are immutable.
#       8 # We cannot change, add, or remove individual items from a tuple.
#
# TypeError: 'tuple' object does not support item assignment
