# %% [markdown]
# ### Using extend() method in list

# %%
cart_items =['t-shirt', 'shoes']

print("Old cart items : ", cart_items)

cart_items.extend(['jeans', 'cap'])
print("\nNew cart items : ", cart_items)
# Out:
# Old cart items :  ['t-shirt', 'shoes']
#
# New cart items :  ['t-shirt', 'shoes', 'jeans', 'cap']
