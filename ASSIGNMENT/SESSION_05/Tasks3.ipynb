# %% [markdown]
# ### Creation of function which remove the last order from the list

# %%
def remove_last_item(order_list):
    return order_list.pop()

# Sample Zomato order list
order_list = ["Pizza", "Burger", "Fries", "Cold Drink"]

# Remove the last item
removed_item = remove_last_item(order_list)

print("Removed item:", removed_item)
print("Updated order list:", order_list)
# Out:
# Removed item: Cold Drink
# Updated order list: ['Pizza', 'Burger', 'Fries']
