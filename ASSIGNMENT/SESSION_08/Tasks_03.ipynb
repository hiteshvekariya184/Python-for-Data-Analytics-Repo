# %% [markdown]
# ## While Loop & Continue Statement

# %%
# Flipkart cart item prices
item_prices = [299, 499, 199, 999, 149]

# Initialize total
total = 0

# Use for loop and continue
for price in item_prices:
    if price < 200:
        continue
    total += price

# Print total of remaining items
print("Total of remaining items:", total)
# Out:
# Total of remaining items: 1797
