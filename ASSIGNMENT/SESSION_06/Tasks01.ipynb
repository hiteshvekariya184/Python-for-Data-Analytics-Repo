# %% [markdown]
# ## Creation of Dictionary

# %%
# Create a dictionary of Spotify playlist names and their prices
playlist_prices = {
    "Daily Mix": 99,
    "Bollywood Beats": 129,
    "Rock Classics": 179
}

# Print the dictionary
print(playlist_prices)
# Out:
# {'Daily Mix': 99, 'Bollywood Beats': 129, 'Rock Classics': 179}
