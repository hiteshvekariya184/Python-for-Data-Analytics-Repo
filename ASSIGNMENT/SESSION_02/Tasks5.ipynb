# %% [markdown]
# ## Representation of indentation & spaces in programs

# %%
sales = 5000

if sales > 3000:
    print("Good sales")
    print("Target achieved")
# Out:
# Good sales
# Target achieved
