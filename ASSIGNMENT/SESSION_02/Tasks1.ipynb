# %% [markdown]
# ## Printing of simple datas

# %%
user_name = "Vekariya Hitesh"
fav_app = "Youtube"
daily_usage_hours = 2

print(f"My name is {user_name}.")
print(f"My favorite app is {fav_app}.")
print(f"I use {fav_app} for about more than {daily_usage_hours} hours every day.")
# Out:
# My name is Vekariya Hitesh.
# My favorite app is Youtube.
# I use Youtube for about more than 2 hours every day.
