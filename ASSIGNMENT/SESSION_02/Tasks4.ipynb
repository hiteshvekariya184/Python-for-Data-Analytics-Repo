# %% [markdown]
# ## Printing a sentence using all three variables in single line

# %%
order_total = 100.00
delivery_region = "North America"
discount_percent = 10.0

print(f'Order from {delivery_region} totals ₹{order_total} with {discount_percent}% discount.')
# Out:
# Order from North America totals ₹100.0 with 10.0% discount.
